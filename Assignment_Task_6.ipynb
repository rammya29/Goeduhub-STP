# %% [markdown]
# <a href="https://colab.research.google.com/github/rammya29/Goeduhub-STP/blob/main/Assignment_Task_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Assignment / Task - 6

# %% [markdown]
# ##This assignment is for visualization using Python Matplotlib Library

# %% [markdown]
# 1. Load the necessary package for plotting using pyplot from matplotlib. Example - Days(x-axis) represents 8 days and Speed represents a car’s speed. Plot a Basic line plot between days and car speed, put x axis label as days and y axis label as car speed and put title Car Speed Measurement.
#
#          Days=[1,2,3,4,5,6,7,8]
#
#          Speed=[60,62,61,58,56,57,46,63]

# %%
import matplotlib
import matplotlib.pyplot as plt
xdays = [1,2,3,4,5,6,7,8]
yspeed = [60,62,61,58,56,57,46,63]

plt.plot(xdays, yspeed)
plt.title("Car Speed Measurments")
plt.xlabel("Days")
plt.ylabel("Car Speed")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
#  2. Now to above car data apply some string formats  like line style example green dotted line, marker shape like +, change markersize, markerface color etc.

# %%
import matplotlib
import matplotlib.pyplot as plt
xdays = [1,2,3,4,5,6,7,8]
yspeed = [60,62,61,58,56,57,46,63]

plt.plot(xdays, yspeed ,'g:+', ms=15, mec='m', mfc='k')
plt.title("Car Speed Measurments")
plt.xlabel("Days")
plt.ylabel("Car Speed")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
#  3. Plot Axes Labels, Chart title, Legend, Grid in Car minimum, Maximum and average speed in 8 days.
#
#      `days=[1,2,3,4,5,6,7,8]`
#
#  `max_speed=[80,91,92,88,77,79,76,75]`
#
#  `min_speed=[42,43,40,42,33,36,34,35]`
#
#  `avg_speed=[46,58,57,56,40,42,41,36]`

# %%
import matplotlib.pyplot as plt
days=[1,2,3,4,5,6,7,8]
max_speed=[80,91,92,88,77,79,76,75]
min_speed=[42,43,40,42,33,36,34,35]
avg_speed=[46,58,57,56,40,42,41,36]

plt.plot(days, max_speed, ":", label = "Maximum_Speed")
plt.plot(days, min_speed, ":", label = "Minimum_Speed")
plt.plot(days, avg_speed, ":", label = "Average_Speed")

plt.grid()
plt.legend()

plt.title("Car Speed Measurement")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# 4. Plotting a basic sine graph by adding more features. Adding Multiple plots by Superimposition like cosine wave.

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0,4*np.pi,0.1)
y = np.sin(x)
z = np.cos(x)
plt.plot(x,y)
plt.plot(x,z)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# 5. Plot Simple bar chart showing popularity of Programming Languages.
#
#  `Languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']`
#
#  `Popularity = [56, 39, 34, 34, 29]`
#
#  `Security = [44 ,36 ,55, 50, 42]`
#
#  Plot Multiple Bars showing Popularity and Security of major Programming Languages. Also Create Horizontal bar chart using barh function.

# %%
import matplotlib.pyplot as plt

Languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
Popularity = [56, 39, 34, 34, 29]
Security = [44 ,36 ,55, 50, 42]

plt.bar(Languages, Popularity,  label = "Popularity")
plt.bar(Languages, Security, width = 0.4, label = "Security")
plt.title("Language")
plt.legend(loc='upper right', frameon=False)
plt.show()

# %%
import matplotlib.pyplot as plt

Languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
Popularity = [56, 39, 34, 34, 29]
Security = [44 ,36 ,55, 50, 42]

plt.barh(Languages, Popularity,  label = "Popularity")
plt.barh(Languages, Security, height = 0.4, label = "Security")
plt.title("Language")
plt.legend(loc='upper right', frameon=False)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# 6.  Plot Histogram, We have a sample data of Students marks of various Students, we will try to plot number of Students by marks range and try to figure out how many Students are average, below-average and Excellent.
#
#  `Marks = [ 61,86,42,46,73,95,65,78,53,92,55,69,70,49,72,86,64]`
#
#  Histogram showing Below Average, Average and Execellent distribution
#
#  `40-60: Below Average`
#
#  `60-80: Average`
#
#  `80-100: Excellent`

# %%
import numpy as np
import matplotlib.pyplot as plt

Marks = [ 61,86,42,46,73,95,65,78,53,92,55,69,70,49,72,86,64]

'''below_avg = Marks[np.logical_and(Marks >= 40 , Marks < 60)]
avg = Marks[np.logical_and(Marks >= 60 , Marks < 80)]
excellent = Marks[np.logical_and(Marks >= 80 , Marks < 100)]'''

plt.ylabel("No. of Students")
plt.xlabel("Marks")
plt.title("Students Marks")
plt.hist(Marks)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# 7.  Titanic Data Set Download Data
#
#  Load the data file
#
#  (i) Create a pie chart presenting the male/female proportion
#
#  (ii) Create a scatterplot with the Fare paid and the Age, differ the plot color by gender

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('/content/titanic.csv')

cnt = data.Sex.value_counts()
plt.pie(cnt, labels = ["Male", "Female"])
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('/content/titanic.csv')

data_male = data[data['Sex'] == 'male']
data_male.Sex.value_counts()

data_female = data[data['Sex'] == 'female']
data_female.Sex.value_counts()

plt.figure(figsize = (10,5)) 
plt.title("Gender")
plt.xlabel("Fare")
plt.ylabel("Age")

plt.scatter(data_male['Fare'], data_male['Age'], label = "Male", color = 'r', marker = '*' )
plt.scatter(data_female['Fare'], data_female['Age'], label = "Female", color = 'm', marker = '+' )
 

plt.legend()

# %% [markdown]
# ---

# %% [markdown]
# #End Of Assignment

# %% [markdown]
# **Author** : Rammya Dharshini K
#
# **Date** : 31-05-2021
#
# **Reg.ID** : GO_STP_1613
